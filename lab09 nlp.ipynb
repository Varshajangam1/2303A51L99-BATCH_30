# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical

# Parameters
batch_size = 64
epochs = 100
latent_dim = 256
input_vocab_size = 100  # adjust based on actual vocab size
target_vocab_size = 100  # adjust based on actual vocab size

# Sample data (use your own dataset)
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# Vocabulary creation
input_texts = [pair[0] for pair in data]
target_texts = [pair[1] for pair in data]

# Create a mapping of unique tokens for both input and target sequences
input_tokens = sorted(set(" ".join(input_texts).split()))
target_tokens = sorted(set(" ".join(target_texts).split()))

input_token_index = dict([(char, i + 1) for i, char in enumerate(input_tokens)])
target_token_index = dict([(char, i + 1) for i, char in enumerate(target_tokens)])

input_vocab_size = len(input_token_index) + 1
target_vocab_size = len(target_token_index) + 1

# Encode sentences into sequences of integers
def encode_text(text, token_index, max_len):
    sequence = [token_index[word] for word in text.split() if word in token_index]
    sequence = sequence + [0] * (max_len - len(sequence))  # Pad sequences
    return sequence

# Determine maximum lengths for padding
max_encoder_seq_length = max([len(text.split()) for text in input_texts])
max_decoder_seq_length = max([len(text.split()) for text in target_texts])

# Prepare the data
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length), dtype="int32")
decoder_input_data = np.zeros((len(target_texts), max_decoder_seq_length), dtype="int32")
decoder_target_data = np.zeros((len(target_texts), max_decoder_seq_length, target_vocab_size), dtype="float32")

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    encoder_input_data[i] = encode_text(input_text, input_token_index, max_encoder_seq_length)
    decoder_input_data[i] = encode_text(target_text, target_token_index, max_decoder_seq_length)
    for t, word in enumerate(target_text.split()):
        if word in target_token_index:
            decoder_target_data[i, t, target_token_index[word]] = 1.0
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[word]] = 1.0  # Shifts the target sequence

# Model definition
# Encoder
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(input_dim=input_vocab_size, output_dim=latent_dim)(encoder_inputs)
encoder_outputs, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(input_dim=target_vocab_size, output_dim=latent_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(target_vocab_size, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer=RMSprop(), loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2
)

# Inference models
# Encoder model for inference
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model for inference
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_embedding, initial_state=decoder_states_inputs
)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

# Translation function
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1))
    start_token_index = 1 if target_token_index else 0  # Default to 0 if empty
    target_seq[0, 0] = start_token_index

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        reverse_target_token_index = dict((i, char) for char, i in target_token_index.items())
        sampled_word = reverse_target_token_index[sampled_token_index]
        decoded_sentence += ' ' + sampled_word

        # Exit condition: either hit max length or find stop character.
        if (sampled_word == '\n' or len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence.strip()

# Test the translation
test_input_seq = np.array(encode_text("hello", input_token_index, max_encoder_seq_length)).reshape(1, -1)
translated_sentence = decode_sequence(test_input_seq)
print("Translated sentence:", translated_sentence)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.3333 - loss: 3.3452 - val_accuracy: 0.0000e+00 - val_loss: 1.7764
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.4667 - loss: 3.2976 - val_accuracy: 0.0000e+00 - val_loss: 1.7951
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 3.2562 - val_accuracy: 0.0000e+00 - val_loss: 1.8140
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.6000 - loss: 3.2138 - val_accuracy: 0.0000e+00 - val_loss: 1.8348
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6000 - loss: 3.1674 - val_accuracy: 0.0000e+00 - val_loss: 1.8587
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.6667 - loss: 3.1145 - val_accuracy: 0.0000e+00 - val_loss: 1.8868
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6667 - loss: 3.0528 - val_accuracy: 0.0000e+00 - val_loss: 1.9204
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6000 - loss: 2.9799 - val_accuracy: 0.0000e+00 - val_loss: 1.9609
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6000 - loss: 2.8932 - val_accuracy: 0.0000e+00 - val_loss: 2.0099
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.6000 - loss: 2.7898 - val_accuracy: 0.0000e+00 - val_loss: 2.0688
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.6000 - loss: 2.6669 - val_accuracy: 0.0000e+00 - val_loss: 2.1385
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6000 - loss: 2.5226 - val_accuracy: 0.0000e+00 - val_loss: 2.2189
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5333 - loss: 2.3571 - val_accuracy: 0.0000e+00 - val_loss: 2.3080
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5333 - loss: 2.1751 - val_accuracy: 0.0000e+00 - val_loss: 2.4021
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5333 - loss: 1.9873 - val_accuracy: 0.0000e+00 - val_loss: 2.4967
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5333 - loss: 1.8090 - val_accuracy: 0.0000e+00 - val_loss: 2.5888
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4667 - loss: 1.6520 - val_accuracy: 0.0000e+00 - val_loss: 2.6798
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4667 - loss: 1.5195 - val_accuracy: 0.0000e+00 - val_loss: 2.7757
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4667 - loss: 1.4082 - val_accuracy: 0.0000e+00 - val_loss: 2.8852
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5333 - loss: 1.3133 - val_accuracy: 0.0000e+00 - val_loss: 3.0181
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5333 - loss: 1.2311 - val_accuracy: 0.0000e+00 - val_loss: 3.1847
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5333 - loss: 1.1584 - val_accuracy: 0.0000e+00 - val_loss: 3.3971
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5333 - loss: 1.0930 - val_accuracy: 0.0000e+00 - val_loss: 3.6690
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5333 - loss: 1.0331 - val_accuracy: 0.0000e+00 - val_loss: 4.0151
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5333 - loss: 0.9785 - val_accuracy: 0.0000e+00 - val_loss: 4.4503
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5333 - loss: 0.9273 - val_accuracy: 0.0000e+00 - val_loss: 4.9559
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4667 - loss: 1.1609 - val_accuracy: 0.0000e+00 - val_loss: 5.3043
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5333 - loss: 0.8713 - val_accuracy: 0.0000e+00 - val_loss: 5.7835
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5333 - loss: 0.8422 - val_accuracy: 0.0000e+00 - val_loss: 6.3967
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4667 - loss: 0.9006 - val_accuracy: 0.0000e+00 - val_loss: 6.8869
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4000 - loss: 1.3682 - val_accuracy: 0.0000e+00 - val_loss: 7.2910
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5333 - loss: 0.9893 - val_accuracy: 0.0000e+00 - val_loss: 7.5992
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.4000 - loss: 0.8694 - val_accuracy: 0.0000e+00 - val_loss: 7.9221
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6000 - loss: 0.7885 - val_accuracy: 0.0000e+00 - val_loss: 8.3098
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4000 - loss: 0.8652 - val_accuracy: 0.0000e+00 - val_loss: 8.6739
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6000 - loss: 0.8249 - val_accuracy: 0.0000e+00 - val_loss: 8.9854
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.4667 - loss: 0.9457 - val_accuracy: 0.0000e+00 - val_loss: 9.6015
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4667 - loss: 0.9776 - val_accuracy: 0.0000e+00 - val_loss: 9.5882
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4000 - loss: 0.8419 - val_accuracy: 0.0000e+00 - val_loss: 9.9879
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 0.7610 - val_accuracy: 0.0000e+00 - val_loss: 10.3593
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.4667 - loss: 0.7623 - val_accuracy: 0.0000e+00 - val_loss: 10.6741
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.4667 - loss: 0.7600 - val_accuracy: 0.0000e+00 - val_loss: 11.0186
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4667 - loss: 0.7558 - val_accuracy: 0.0000e+00 - val_loss: 11.2968
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.4667 - loss: 0.7535 - val_accuracy: 0.0000e+00 - val_loss: 11.6619
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.4667 - loss: 0.7515 - val_accuracy: 0.0000e+00 - val_loss: 11.7925
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4667 - loss: 0.7557 - val_accuracy: 0.0000e+00 - val_loss: 12.3213
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6000 - loss: 0.7788 - val_accuracy: 0.0000e+00 - val_loss: 12.1334
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4000 - loss: 0.8208 - val_accuracy: 0.0000e+00 - val_loss: 12.6928
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6000 - loss: 0.8333 - val_accuracy: 0.0000e+00 - val_loss: 13.0515
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4667 - loss: 0.8270 - val_accuracy: 0.0000e+00 - val_loss: 13.0498
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6000 - loss: 0.7766 - val_accuracy: 0.0000e+00 - val_loss: 13.8201
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5333 - loss: 0.7931 - val_accuracy: 0.0000e+00 - val_loss: 13.2943
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5333 - loss: 0.7618 - val_accuracy: 0.0000e+00 - val_loss: 14.3879
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 0.7903 - val_accuracy: 0.0000e+00 - val_loss: 13.5743
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4667 - loss: 0.7503 - val_accuracy: 0.0000e+00 - val_loss: 14.8224
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4667 - loss: 0.7873 - val_accuracy: 0.0000e+00 - val_loss: 13.9359
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4667 - loss: 0.7455 - val_accuracy: 0.0000e+00 - val_loss: 15.2474
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.4667 - loss: 0.7808 - val_accuracy: 0.0000e+00 - val_loss: 14.2564
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4667 - loss: 0.7414 - val_accuracy: 0.0000e+00 - val_loss: 15.5930
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 0.7735 - val_accuracy: 0.0000e+00 - val_loss: 14.6274
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5333 - loss: 0.7385 - val_accuracy: 0.0000e+00 - val_loss: 15.9400
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.4667 - loss: 0.7714 - val_accuracy: 0.0000e+00 - val_loss: 14.8832
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5333 - loss: 0.7393 - val_accuracy: 0.0000e+00 - val_loss: 16.2693
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4667 - loss: 0.7717 - val_accuracy: 0.0000e+00 - val_loss: 15.1975
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5333 - loss: 0.7354 - val_accuracy: 0.0000e+00 - val_loss: 16.3652
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4667 - loss: 0.7637 - val_accuracy: 0.0000e+00 - val_loss: 15.4866
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5333 - loss: 0.7467 - val_accuracy: 0.0000e+00 - val_loss: 16.8836
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 0.7684 - val_accuracy: 0.0000e+00 - val_loss: 15.8599
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 0.7228 - val_accuracy: 0.0000e+00 - val_loss: 16.5138
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4667 - loss: 0.7403 - val_accuracy: 0.0000e+00 - val_loss: 16.3083
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5333 - loss: 0.7372 - val_accuracy: 0.0000e+00 - val_loss: 16.8376
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.4667 - loss: 0.7454 - val_accuracy: 0.0000e+00 - val_loss: 16.4854
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.5333 - loss: 0.7429 - val_accuracy: 0.0000e+00 - val_loss: 17.3714
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.4667 - loss: 0.7424 - val_accuracy: 0.0000e+00 - val_loss: 16.4364
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.4667 - loss: 0.7572 - val_accuracy: 0.0000e+00 - val_loss: 17.6798
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.4000 - loss: 0.7463 - val_accuracy: 0.0000e+00 - val_loss: 16.6419
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.4667 - loss: 0.7321 - val_accuracy: 0.0000e+00 - val_loss: 17.4457
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.4000 - loss: 0.7171 - val_accuracy: 0.0000e+00 - val_loss: 17.1306
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.6000 - loss: 0.7327 - val_accuracy: 0.0000e+00 - val_loss: 17.5755
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.4000 - loss: 0.7127 - val_accuracy: 0.0000e+00 - val_loss: 17.3899
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.6000 - loss: 0.7468 - val_accuracy: 0.0000e+00 - val_loss: 17.8855
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.4000 - loss: 0.7190 - val_accuracy: 0.0000e+00 - val_loss: 17.5187
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.6000 - loss: 0.7412 - val_accuracy: 0.0000e+00 - val_loss: 18.2439
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.4667 - loss: 0.7243 - val_accuracy: 0.0000e+00 - val_loss: 17.4658
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.5333 - loss: 0.7352 - val_accuracy: 0.0000e+00 - val_loss: 18.5480
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4667 - loss: 0.7269 - val_accuracy: 0.0000e+00 - val_loss: 17.5033
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.4667 - loss: 0.7282 - val_accuracy: 0.0000e+00 - val_loss: 18.6285
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.4667 - loss: 0.7175 - val_accuracy: 0.0000e+00 - val_loss: 17.9175
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.4667 - loss: 0.7253 - val_accuracy: 0.0000e+00 - val_loss: 18.5600
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.4000 - loss: 0.7054 - val_accuracy: 0.0000e+00 - val_loss: 18.3050
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.5333 - loss: 0.7312 - val_accuracy: 0.0000e+00 - val_loss: 18.4565
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.4000 - loss: 0.6971 - val_accuracy: 0.0000e+00 - val_loss: 18.5575
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.5333 - loss: 0.7407 - val_accuracy: 0.0000e+00 - val_loss: 18.4020
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.4000 - loss: 0.6928 - val_accuracy: 0.0000e+00 - val_loss: 18.6672
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.5333 - loss: 0.7419 - val_accuracy: 0.0000e+00 - val_loss: 18.4603
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.4000 - loss: 0.6910 - val_accuracy: 0.0000e+00 - val_loss: 18.6612
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.5333 - loss: 0.7368 - val_accuracy: 0.0000e+00 - val_loss: 18.5850
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4000 - loss: 0.6939 - val_accuracy: 0.0000e+00 - val_loss: 18.5629
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6000 - loss: 0.7300 - val_accuracy: 0.0000e+00 - val_loss: 18.7637
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.4000 - loss: 0.7017 - val_accuracy: 0.0000e+00 - val_loss: 18.3097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Translated sentence: bonjour
